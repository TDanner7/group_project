# %%
#imports
import requests
import pandas as pd
from datetime import datetime as dt
import hvplot.pandas
from dotenv import load_dotenv
import os
from geopy.geocoders import Nominatim
from geopy.exc import GeocoderTimedOut
import time
import seaborn as sns
import matplotlib.pyplot as plt

load_dotenv()
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(
#     > .cell-output-ipywidget-background > .lm-Widget > *[data-root-id]
#   ),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# True

# %%
#set API key
api_key = os.getenv('CENSUS_API_KEY')

# %%
#import data
#https://api.census.gov/data/timeseries/intltrade/exports/hs?get=CTY_NAME,CTY_CODE,ALL_VAL_YR&time=2022-12&key=4b47fff787a4802c4e94f1d177840dd265a548f8
base_uri = 'https://api.census.gov/data/timeseries/intltrade/exports/hs'
fields = 'CTY_NAME,CTY_CODE,ALL_VAL_YR'
time = '2013-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

#
us_exports_by_cty_2013_df = pd.DataFrame(data)
us_exports_by_cty_2013_df.drop(us_exports_by_cty_2013_df.head(1).index, inplace=True)
us_exports_by_cty_2013_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2013_df.set_index('cty', inplace=True)
us_exports_by_cty_2013_df['amount'] = pd.to_numeric(us_exports_by_cty_2013_df['amount'])
us_exports_by_cty_2013_df['year'] = pd.to_datetime(us_exports_by_cty_2013_df['year'])
us_exports_by_cty_2013_df['year']  = us_exports_by_cty_2013_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2013_df = us_exports_by_cty_2013_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2013_df = us_exports_by_cty_2013_df.sort_values('amount', ascending=False)

# %%
time = '2014-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2014_df = pd.DataFrame(data)
us_exports_by_cty_2014_df.drop(us_exports_by_cty_2014_df.head(1).index, inplace=True)
us_exports_by_cty_2014_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2014_df.set_index('cty', inplace=True)
us_exports_by_cty_2014_df['amount'] = pd.to_numeric(us_exports_by_cty_2014_df['amount'])
us_exports_by_cty_2014_df['year'] = pd.to_datetime(us_exports_by_cty_2014_df['year'])
us_exports_by_cty_2014_df['year']  = us_exports_by_cty_2014_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2014_df = us_exports_by_cty_2014_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2014_df = us_exports_by_cty_2014_df.sort_values('amount', ascending=False)

# %%
time = '2015-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2015_df = pd.DataFrame(data)
us_exports_by_cty_2015_df.drop(us_exports_by_cty_2015_df.head(1).index, inplace=True)
us_exports_by_cty_2015_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2015_df.set_index('cty', inplace=True)
us_exports_by_cty_2015_df['amount'] = pd.to_numeric(us_exports_by_cty_2015_df['amount'])
us_exports_by_cty_2015_df['year'] = pd.to_datetime(us_exports_by_cty_2015_df['year'])
us_exports_by_cty_2015_df['year']  = us_exports_by_cty_2015_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2015_df = us_exports_by_cty_2015_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2015_df = us_exports_by_cty_2015_df.sort_values('amount', ascending=False)

# %%
time = '2016-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2016_df = pd.DataFrame(data)
us_exports_by_cty_2016_df.drop(us_exports_by_cty_2016_df.head(1).index, inplace=True)
us_exports_by_cty_2016_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2016_df.set_index('cty', inplace=True)
us_exports_by_cty_2016_df['amount'] = pd.to_numeric(us_exports_by_cty_2016_df['amount'])
us_exports_by_cty_2016_df['year'] = pd.to_datetime(us_exports_by_cty_2016_df['year'])
us_exports_by_cty_2016_df['year']  = us_exports_by_cty_2016_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2016_df = us_exports_by_cty_2016_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2016_df = us_exports_by_cty_2016_df.sort_values('amount', ascending=False)

# %%
time = '2017-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2017_df = pd.DataFrame(data)
us_exports_by_cty_2017_df.drop(us_exports_by_cty_2017_df.head(1).index, inplace=True)
us_exports_by_cty_2017_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2017_df.set_index('cty', inplace=True)
us_exports_by_cty_2017_df['amount'] = pd.to_numeric(us_exports_by_cty_2017_df['amount'])
us_exports_by_cty_2017_df['year'] = pd.to_datetime(us_exports_by_cty_2017_df['year'])
us_exports_by_cty_2017_df['year']  = us_exports_by_cty_2017_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2017_df = us_exports_by_cty_2017_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2017_df = us_exports_by_cty_2017_df.sort_values('amount', ascending=False)

# %%
time = '2018-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2018_df = pd.DataFrame(data)
us_exports_by_cty_2018_df.drop(us_exports_by_cty_2018_df.head(1).index, inplace=True)
us_exports_by_cty_2018_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2018_df.set_index('cty', inplace=True)
us_exports_by_cty_2018_df['amount'] = pd.to_numeric(us_exports_by_cty_2018_df['amount'])
us_exports_by_cty_2018_df['year'] = pd.to_datetime(us_exports_by_cty_2018_df['year'])
us_exports_by_cty_2018_df['year']  = us_exports_by_cty_2018_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2018_df = us_exports_by_cty_2018_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2018_df = us_exports_by_cty_2018_df.sort_values('amount', ascending=False)

# %%
time = '2019-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2019_df = pd.DataFrame(data)
us_exports_by_cty_2019_df.drop(us_exports_by_cty_2019_df.head(1).index, inplace=True)
us_exports_by_cty_2019_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2019_df.set_index('cty', inplace=True)
us_exports_by_cty_2019_df['amount'] = pd.to_numeric(us_exports_by_cty_2019_df['amount'])
us_exports_by_cty_2019_df['year'] = pd.to_datetime(us_exports_by_cty_2019_df['year'])
us_exports_by_cty_2019_df['year']  = us_exports_by_cty_2019_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2019_df = us_exports_by_cty_2019_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2019_df = us_exports_by_cty_2019_df.sort_values('amount', ascending=False)

# %%
time = '2020-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2020_df = pd.DataFrame(data)
us_exports_by_cty_2020_df.drop(us_exports_by_cty_2020_df.head(1).index, inplace=True)
us_exports_by_cty_2020_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2020_df.set_index('cty', inplace=True)
us_exports_by_cty_2020_df['amount'] = pd.to_numeric(us_exports_by_cty_2020_df['amount'])
us_exports_by_cty_2020_df['year'] = pd.to_datetime(us_exports_by_cty_2020_df['year'])
us_exports_by_cty_2020_df['year']  = us_exports_by_cty_2020_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2020_df = us_exports_by_cty_2020_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2020_df = us_exports_by_cty_2020_df.sort_values('amount', ascending=False)

# %%
time = '2021-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2021_df = pd.DataFrame(data)
us_exports_by_cty_2021_df.drop(us_exports_by_cty_2021_df.head(1).index, inplace=True)
us_exports_by_cty_2021_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2021_df.set_index('cty', inplace=True)
us_exports_by_cty_2021_df['amount'] = pd.to_numeric(us_exports_by_cty_2021_df['amount'])
us_exports_by_cty_2021_df['year'] = pd.to_datetime(us_exports_by_cty_2021_df['year'])
us_exports_by_cty_2021_df['year']  = us_exports_by_cty_2021_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2021_df = us_exports_by_cty_2021_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2021_df = us_exports_by_cty_2021_df.sort_values('amount', ascending=False)

# %%
time = '2022-12'

r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
data = r.json()

us_exports_by_cty_2022_df = pd.DataFrame(data)
us_exports_by_cty_2022_df.drop(us_exports_by_cty_2022_df.head(1).index, inplace=True)
us_exports_by_cty_2022_df.columns = ['cty', 'cty_code', 'amount', 'year']
us_exports_by_cty_2022_df.set_index('cty', inplace=True)
us_exports_by_cty_2022_df['amount'] = pd.to_numeric(us_exports_by_cty_2022_df['amount'])
us_exports_by_cty_2022_df['year'] = pd.to_datetime(us_exports_by_cty_2022_df['year'])
us_exports_by_cty_2022_df['year']  = us_exports_by_cty_2022_df['year'] .dt.strftime('%Y-%m')
us_exports_by_cty_2022_df = us_exports_by_cty_2022_df.drop(['TOTAL FOR ALL COUNTRIES'])
us_exports_by_cty_2022_df = us_exports_by_cty_2022_df.sort_values('amount', ascending=False)

# %% [markdown]
# # Total Export Amount By Top 3 Trade Pacts By Year

# %%
#find the top five trade partners for each year
top_2013_export_cty = us_exports_by_cty_2013_df.head(5)
top_2014_export_cty = us_exports_by_cty_2014_df.head(5)
top_2015_export_cty = us_exports_by_cty_2015_df.head(5)
top_2016_export_cty = us_exports_by_cty_2016_df.head(5)
top_2017_export_cty = us_exports_by_cty_2017_df.head(5)
top_2018_export_cty = us_exports_by_cty_2018_df.head(5)
top_2019_export_cty = us_exports_by_cty_2019_df.head(5)
top_2020_export_cty = us_exports_by_cty_2020_df.head(5)
top_2021_export_cty = us_exports_by_cty_2021_df.head(5)
top_2022_export_cty = us_exports_by_cty_2022_df.head(5)

# %%
top_us_trade_agreements_df = pd.concat([top_2013_export_cty,
                                          top_2014_export_cty,
                                          top_2015_export_cty,
                                          top_2016_export_cty,
                                          top_2017_export_cty,
                                          top_2018_export_cty,
                                          top_2019_export_cty,
                                          top_2020_export_cty,
                                          top_2021_export_cty,
                                          top_2022_export_cty],axis=0)


top_us_trade_agreements_df = top_us_trade_agreements_df.drop(['cty_code'], axis=1)
top_us_trade_agreements_df['year'] = pd.to_datetime(top_us_trade_agreements_df['year'], format='%Y-%m')
top_us_trade_agreements_df['year'] = top_us_trade_agreements_df['year'].dt.strftime('%Y')
top_us_trade_agreements_df.head()
# Out:
#                      amount  year
# cty
# OECD           996648149665  2013
# APEC           970076134975  2013
# NATO           562222735042  2013
# NORTH AMERICA  526728646420  2013
# NAFTA          526709236757  2013

# %%
top_us_trade_agreements_df.hvplot.bar(x="cty", y="amount",ylabel='Dollars', xlabel= 'Trade Partner', rot=45, title='Top US Exports by Year', groupby='year').opts(yformatter='$%.0f')
# Out:
# :DynamicMap   [year]
#    :Bars   [cty]   (amount)

# %%
#reset index to plot and plot top 5 trade acts

top_us_trade_agreements_df.reset_index(inplace=True)

# %%
#groupby to find totals
total_pact_exports = top_us_trade_agreements_df.groupby('cty').sum('amount')
total_pact_exports['amount'] = pd.to_numeric(total_pact_exports['amount'])
total_pact_exports['amount']
# Out:
# cty
# APEC             10047469440739
# NAFTA             5472560020138
# NATO              5966062549654
# NORTH AMERICA     5472671350232
# OECD             10702960381536
# Name: amount, dtype: int64

# %%
#create plot

plt.figure(figsize=(12, 8))
sns.barplot(data=(top_us_trade_agreements_df.rename({'cty': 'Export Pact'}, axis='columns')), y='amount', x='year', hue='Export Pact').set(xlabel ="Year", ylabel = "Yearly Value in USD $1 Trillions", title ='Top US Export Pact + North America').set(xlabel ="Year", ylabel = "YTD Value USD", title ='Top US Export Pacts')
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[47], line 2
#       1 plt.figure(figsize=(12, 8))
# ----> 2 sns.barplot(data=(top_us_trade_agreements_df.rename({'cty': 'Export Pact'}, axis='columns')), y='amount', x='year', hue='Export Pact').set(xlabel ="Year", ylabel = "Yearly Value in USD $1 Trillions", title ='Top US Export Pact + North America').set(xlabel ="Year", ylabel = "YTD Value USD", title ='Top US Export Pacts')
#
# AttributeError: 'list' object has no attribute 'set'

# %%
#create a df to present the top 5 trade partners for the past decade
us_exports_by_cty_10_year_df = pd.concat([top_2013_export_cty,
                                          top_2014_export_cty,
                                          top_2015_export_cty,
                                          top_2016_export_cty,
                                          top_2017_export_cty,
                                          top_2018_export_cty,
                                          top_2019_export_cty,
                                          top_2020_export_cty,
                                          top_2021_export_cty,
                                          top_2022_export_cty],axis=0, keys=['2013','2014','2015','2016','2017','2018','2019','2020','2021','2022'])

# %%
#remove columns we do not need
us_exports_by_cty_format_df = us_exports_by_cty_10_year_df.drop(['cty_code', 'year'], axis=1)
us_exports_by_cty_format_df.head(50)
# Out:
#                            amount
#      cty
# 2013 OECD            996648149665
#      APEC            970076134975
#      NATO            562222735042
#      NORTH AMERICA   526728646420
#      NAFTA           526709236757
# 2014 OECD           1038989601049
#      APEC           1003010860056
#      NATO            586008831697
#      NORTH AMERICA   553836809604
#      NAFTA           553824112775
# 2015 OECD            985645992043
#      APEC            936442035089
#      NATO            546893410511
#      NORTH AMERICA   517323613361
#      NAFTA           517315306351
# 2016 OECD            958029565758
#      APEC            905563779737
#      NATO            530677051989
#      NORTH AMERICA   496967411539
#      NAFTA           496963299123
# 2017 OECD           1014426375214
#      APEC            972913072325
#      NATO            560638977011
#      NORTH AMERICA   526393079805
#      NAFTA           526382804521
# 2018 OECD           1108935316994
# ...

# %% [markdown]
# # Change Year / Year for top Trade Pact

# %%
#remove unwanted pacts then plot the percent change year over year
oecd_change_df = top_us_trade_agreements_df
oecd_change_df = oecd_change_df[oecd_change_df["cty"].str.contains("APEC|NATO|NORTH AMERICA|NAFTA") == False]
oecd_change_df = oecd_change_df.drop(['cty'], axis=1)
oecd_change_df.set_index('year', inplace=True)
oecd_change_df = oecd_change_df.pct_change()
oecd_change_df['PACT'] = 'OCED'
oecd_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
apec_change_df = top_us_trade_agreements_df
apec_change_df = apec_change_df[apec_change_df["cty"].str.contains("OECD|NATO|NORTH AMERICA|NAFTA") == False]
apec_change_df = apec_change_df.drop(['cty'], axis=1)
apec_change_df.set_index('year', inplace=True)
apec_change_df = apec_change_df.pct_change()
apec_change_df['PACT'] = 'APEC'
apec_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
nato_change_df = top_us_trade_agreements_df
nato_change_df = nato_change_df[nato_change_df["cty"].str.contains("OECD|APEC|NORTH AMERICA|NAFTA") == False]
nato_change_df = nato_change_df.drop(['cty'], axis=1)
nato_change_df.set_index('year', inplace=True)
nato_change_df = nato_change_df.pct_change()
nato_change_df['PACT'] = 'NATO'
nato_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
na_change_df = top_us_trade_agreements_df
na_change_df = na_change_df[na_change_df["cty"].str.contains("OECD|NATO|APEC|NAFTA") == False]
na_change_df = na_change_df.drop(['cty'], axis=1)
na_change_df.set_index('year', inplace=True)
na_change_df = na_change_df.pct_change()
na_change_df['PACT'] = 'NORTH AMERICA'
na_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
nafta_change_df = top_us_trade_agreements_df
nafta_change_df = nafta_change_df[nafta_change_df["cty"].str.contains("OECD|NATO|NORTH AMERICA|APEC") == False]
nafta_change_df = nafta_change_df.drop(['cty'], axis=1)
nafta_change_df.set_index('year', inplace=True)
nafta_change_df = nafta_change_df.pct_change()
nafta_change_df['PACT'] = 'NAFTA'
nafta_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
#combine plots to see them together
oecd_change_df.hvplot(label='OECD').opts(title="Percent Change in Top US Export Pacts + North America",ylabel='Percent', xlabel= 'Year') * apec_change_df.hvplot(label='APEC') * nato_change_df.hvplot(label='NATO') * na_change_df.hvplot(label='NORTH AMERICA') * nafta_change_df.hvplot(label='NAFTA')
# Out:
# :Overlay
#    .Curve.OECD          :Curve   [year]   (amount)
#    .Curve.APEC          :Curve   [year]   (amount)
#    .Curve.NATO          :Curve   [year]   (amount)
#    .Curve.NORTH_AMERICA :Curve   [year]   (amount)
#    .Curve.NAFTA         :Curve   [year]   (amount)

# %% [markdown]
# # Total Export Amount By Top 3 Country By Year

# %%
#drop pacts from the dataframe to find top countries

top_us_cty_wo_pacts_2013 = us_exports_by_cty_2013_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2014 = us_exports_by_cty_2014_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2015 = us_exports_by_cty_2015_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2016 = us_exports_by_cty_2016_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2017 = us_exports_by_cty_2017_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2018 = us_exports_by_cty_2018_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2019 = us_exports_by_cty_2019_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2020 = us_exports_by_cty_2020_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2021 = us_exports_by_cty_2021_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])
top_us_cty_wo_pacts_2022 = us_exports_by_cty_2022_df.drop(['OECD', 'ASIA','PACIFIC RIM COUNTRIES', 'NATO', 'NORTH AMERICA', 'NAFTA', 'EUROPE', 'TWENTY LATIN AMERICAN REPUBLICS', 'LAFTA', 'EUROPEAN UNION', 'EURO AREA', 'ASEAN', 'SOUTH AMERICA', 'AFRICA', 'CENTRAL AMERICA', 'APEC'])

# %%
#Select top 3 ountry from each year

top_us_trade_cty13 = top_us_cty_wo_pacts_2013.head(3)
top_us_trade_cty14 = top_us_cty_wo_pacts_2014.head(3)
top_us_trade_cty15 = top_us_cty_wo_pacts_2015.head(3)
top_us_trade_cty16 = top_us_cty_wo_pacts_2016.head(3)
top_us_trade_cty17 = top_us_cty_wo_pacts_2017.head(3)
top_us_trade_cty18 = top_us_cty_wo_pacts_2018.head(3)
top_us_trade_cty19 = top_us_cty_wo_pacts_2019.head(3)
top_us_trade_cty20 = top_us_cty_wo_pacts_2020.head(3)
top_us_trade_cty21 = top_us_cty_wo_pacts_2021.head(3)
top_us_trade_cty22 = top_us_cty_wo_pacts_2022.head(3)

# %%
total_exports = pd.concat([top_us_trade_cty13,
                                          top_us_trade_cty14,
                                          top_us_trade_cty15,
                                          top_us_trade_cty16,
                                          top_us_trade_cty17,
                                          top_us_trade_cty18,
                                          top_us_trade_cty19,
                                          top_us_trade_cty20,
                                          top_us_trade_cty21,
                                          top_us_trade_cty22],axis=0)


total_exports = total_exports.drop(['cty_code'], axis=1)
total_exports['year'] = pd.to_datetime(total_exports['year'], format='%Y-%m')
total_exports['year'] = total_exports['year'].dt.strftime('%Y')
# total_exports.hvplot.bar(x="cty", y="amount",ylabel='Dollars', xlabel= 'Trade Partner', rot=45, title='Top US Exports by Year', groupby='year').opts(yformatter='$%.0f')
total_exports
# Out:
#               amount  year
# cty
# CANADA  300754868974  2013
# MEXICO  225954367783  2013
# CHINA   121746188637  2013
# CANADA  312816950458  2014
# MEXICO  241007162317  2014
# CHINA   123657203406  2014
# CANADA  280855169199  2015
# MEXICO  236460137152  2015
# CHINA   115873365314  2015
# CANADA  266734465220  2016
# MEXICO  230228833903  2016
# CHINA   115594784477  2016
# CANADA  282773829896  2017
# MEXICO  243608974625  2017
# CHINA   129997227243  2017
# CANADA  299731711825  2018
# MEXICO  265968016784  2018
# CHINA   120281213791  2018
# CANADA  292820257565  2019
# MEXICO  256676487323  2019
# CHINA   106481217316  2019
# CANADA  256212256538  2020
# MEXICO  212512806763  2020
# CHINA   124581510375  2020
# CANADA  309604001291  2021
# MEXICO  277077631592  2021
# CHINA   151431944117  2021
# CANADA  356452564116  2022
# MEXICO  324309526814  2022
# CHINA   154012073132  2022

# %%
#use HVplot to visualize the countries with a year dropdown

total_exports.hvplot.bar(x="cty", y="amount",ylabel='Dollars', xlabel= 'Trade Partner', rot=45, title='Top 3 US Export Countries by Year', groupby='year').opts(yformatter='$%.0f')
# Out:
# :DynamicMap   [year]
#    :Bars   [cty]   (amount)

# %%
#make the amount inot an int

total_exports['amount'] = pd.to_numeric(total_exports['amount'])

# %%
#reset index so that I can graph the data using cty

total_exports.reset_index(inplace=True)

# %%
#create a plot using sns to visualize the top countries by year
plt.figure(figsize=(12, 8))
sns.barplot(data=total_exports, y='amount', x='year', hue='cty').set(xlabel ="Year", ylabel = "Yearly Value in USD $100 Billions", title ='Top US Export Countries')
plt.legend(title='Export Country')

# %% [markdown]
# # Change Year / Year for top Trade Country

# %%
china_change_df = total_exports
china_change_df = china_change_df[china_change_df["cty"].str.contains("MEXICO|CANADA") == False]
china_change_df = china_change_df.drop(['cty'], axis=1)
china_change_df.set_index('year', inplace=True)
china_change_df = china_change_df.pct_change()
china_change_df['Country'] = 'CHINA'
china_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
mexico_change_df = total_exports
mexico_change_df = mexico_change_df[mexico_change_df["cty"].str.contains("CHINA|CANADA") == False]
mexico_change_df = mexico_change_df.drop(['cty'], axis=1)
mexico_change_df.set_index('year', inplace=True)
mexico_change_df = mexico_change_df.pct_change()
mexico_change_df['Country'] = 'MEXICO'
mexico_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
canada_change_df = total_exports
canada_change_df = canada_change_df[canada_change_df["cty"].str.contains("MEXICO|CHINA") == False]
canada_change_df = canada_change_df.drop(['cty'], axis=1)
canada_change_df.set_index('year', inplace=True)
canada_change_df = canada_change_df.pct_change()
canada_change_df['Country'] = 'CANADA'
canada_change_df.hvplot()
# Out:
# :Curve   [year]   (amount)

# %%
mexico_change_df.hvplot(label='MEXICO').opts(title="Percent Change in Top US Export Countries",ylabel='Percent', xlabel= 'Year') * china_change_df.hvplot(label='CHINA') * canada_change_df.hvplot(label='CANADA')
# Out:
# :Overlay
#    .Curve.MEXICO :Curve   [year]   (amount)
#    .Curve.CHINA  :Curve   [year]   (amount)
#    .Curve.CANADA :Curve   [year]   (amount)

# %% [markdown]
# # Total Export Amount By Country

# %%
total_exports.groupby('cty').sum('amount').hvplot.bar().opts(yformatter='$%.0f')
# Out:
# :Bars   [cty]   (amount)

# %%
total_cty_exports = total_exports.groupby('cty').sum('amount')
total_cty_exports['amount'] = pd.to_numeric(total_cty_exports['amount'])
total_cty_exports['amount']
# Out:
# cty
# CANADA    2958756075082
# CHINA     1263656727808
# MEXICO    2513803945056
# Name: amount, dtype: int64

# %% [markdown]
# # Top commodity

# %% [markdown]
# (did not use)

# %%
# fields = 'E_COMMODITY,E_COMMODITY_SDESC,ALL_VAL_YR'
# time = '2013-12'

# r = requests.get(f'{base_uri}?get={fields}&time={time}&key={api_key}')
# data = r.json()

# us_exports_by_com_2013_df = pd.DataFrame(data)
# # us_exports_by_cty_2013_df.drop(us_exports_by_cty_2013_df.head(1).index, inplace=True)
# us_exports_by_com_2013_df.columns = ['code', 'commodity', 'amount', 'year']
# # us_exports_by_cty_2013_df.set_index('cty', inplace=True)
# # us_exports_by_com_2013_df['amount'] = pd.to_numeric(us_exports_by_com_2013_df['amount'])
# # us_exports_by_com_2013_df['year'] = pd.to_datetime(us_exports_by_com_2013_df['year'])
# # us_exports_by_com_2013_df['year']  = us_exports_by_com_2013_df['year'] .dt.strftime('%Y-%m')
# # us_exports_by_com_2013_df = us_exports_by_com_2013_df.drop(['TOTAL FOR ALL COUNTRIES'])
# # us_exports_by_com_2013_df = us_exports_by_com_2013_df.sort_values('amount', ascending=False)
# us_exports_by_com_2013_df
